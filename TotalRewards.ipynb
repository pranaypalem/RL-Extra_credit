# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import DDPG, TD3, SAC
from sb3_contrib import TQC as D4PG
import torch
import pandas as pd
import os
from stable_baselines3.common.callbacks import BaseCallback
from torch import nn

# Set random seed
RANDOM_SEED = 42

# Directory to save models and data
SAVE_DIR = "Output"
os.makedirs(SAVE_DIR, exist_ok=True)

def select_device():
    return torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ContinuousToDiscreteWrapper(gym.ActionWrapper):
    """
    Custom wrapper to convert continuous actions to discrete actions.
    """
    def __init__(self, env):
        super(ContinuousToDiscreteWrapper, self).__init__(env)
        self.action_space = gym.spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)

    def action(self, action):
        # Convert continuous action to discrete action (0 or 1)
        return 0 if action < 0 else 1

class RewardCallback(BaseCallback):
    """
    Custom callback for saving episode rewards.
    """
    def __init__(self):
        super(RewardCallback, self).__init__()
        self.episode_rewards = []
        self.episode_reward = 0

    def _on_step(self) -> bool:
        self.episode_reward += self.locals.get("rewards", 0)
        if self.locals.get("dones"):
            self.episode_rewards.append(self.episode_reward)
            self.episode_reward = 0
        return True

def train_and_evaluate(model_class, env, timesteps=100000, model_name="model"): 
    """
    Train a model using the specified RL algorithm and evaluate its rewards.
    """
    policy_kwargs = dict(net_arch=[256, 256], activation_fn=nn.ReLU)
    model = model_class("MlpPolicy", env, verbose=1, seed=RANDOM_SEED, device=select_device(), policy_kwargs=policy_kwargs)
    callback = RewardCallback()
    model.learn(total_timesteps=timesteps, callback=callback)
    model.save(os.path.join(SAVE_DIR, model_name))  # Save the model after training
    return callback.episode_rewards

def save_training_data(all_rewards):
    """
    Save rewards data for each model in a DataFrame and save as pkl.
    """
    rewards_df = pd.DataFrame(dict([(algo_name, pd.Series(rewards)) for algo_name, rewards in all_rewards.items()]))
    rewards_df.to_pickle(os.path.join(SAVE_DIR, "training_rewards.pkl"))
    print("Training data saved to training_rewards.pkl")

def plot_saved_data(pkl_file):
    """
    Plot rewards from saved pkl file.
    """
    rewards_df = pd.read_pickle(pkl_file)
    rewards_df = rewards_df.dropna(how='all', axis=1)

    if rewards_df.empty:
        print("No rewards data to plot.")
        return

    # Plot each algorithm separately
    for column in rewards_df.columns:
        plt.figure(figsize=(10, 6))
        plt.plot(rewards_df.index, rewards_df[column], label=column)
        plt.xlabel("Episodes")
        plt.ylabel("Total Reward")
        plt.ylim((0,550))
        plt.title(f"Training Rewards for {column} on CartPole-v1")
        plt.legend()
        plt.grid()
        plt.show()

def render_saved_model(model_path, env_name):
    """
    Load a saved model and render the environment.
    """
    env = gym.make(env_name, render_mode="human")
    env = ContinuousToDiscreteWrapper(env)
    model = SAC.load(model_path)  # Example: Load a saved SAC model
    obs, info = env.reset()
    done, truncated = False, False
    while not (done or truncated):
        action, _ = model.predict(obs)
        obs, reward, done, truncated, info = env.step(action)
    env.close()

def main():
    # Set up environment and seed
    env_name = "CartPole-v1"
    env = gym.make(env_name)
    env = ContinuousToDiscreteWrapper(env)  # Wrap the environment to convert continuous actions to discrete
    env.action_space.seed(RANDOM_SEED)
    torch.manual_seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    
    # Algorithms to evaluate
    algorithms = {
        "DDPG": DDPG,
        "TD3": TD3,
        "SAC": SAC,
        "D4PG": D4PG
    }

    # Train and collect rewards for each algorithm
    all_rewards = {}
    timesteps = 10000
    for algo_name, algo_class in algorithms.items():
        print(f"Training {algo_name}...")
        model_name = f"{algo_name}_cartpole"
        all_rewards[algo_name] = train_and_evaluate(algo_class, env, timesteps, model_name=model_name)
    
    # Save training data
    save_training_data(all_rewards)
    
    # Plot saved data
    plot_saved_data(os.path.join(SAVE_DIR, "training_rewards.pkl"))
    
    # Render one of the saved models
    render_saved_model(os.path.join(SAVE_DIR, "SAC_cartpole.zip"), env_name)

if __name__ == "__main__":
    main()
# Out:
# 2024-12-06 17:11:30.551286: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-06 17:11:30.559999: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733530290.569733   70589 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733530290.572825   70589 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-06 17:11:30.584217: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training DDPG...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 20       |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 9951     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 80       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 22.2     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 443      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 178      |
# | train/             |          |
# |    actor_loss      | -1.28    |
# |    critic_loss     | 0.00462  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 20.2     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 409      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 243      |
# | train/             |          |
# |    actor_loss      | -1.58    |
# |    critic_loss     | 0.011    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 142      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.6     |
# |    ep_rew_mean     | 17.6     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 384      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 281      |
# | train/             |          |
# |    actor_loss      | -1.67    |
# |    critic_loss     | 0.0271   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 180      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 16       |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 370      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 320      |
# | train/             |          |
# |    actor_loss      | -1.78    |
# |    critic_loss     | 0.0334   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 219      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.9     |
# |    ep_rew_mean     | 14.9     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 361      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 358      |
# | train/             |          |
# |    actor_loss      | -2.02    |
# |    critic_loss     | 0.0282   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 257      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 14.2     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 354      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 398      |
# | train/             |          |
# |    actor_loss      | -2.13    |
# |    critic_loss     | 0.0145   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.7     |
# |    ep_rew_mean     | 13.7     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 349      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 438      |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 0.0427   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 337      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.2     |
# |    ep_rew_mean     | 13.2     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 346      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 474      |
# | train/             |          |
# |    actor_loss      | -2.41    |
# |    critic_loss     | 0.0291   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 373      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.8     |
# |    ep_rew_mean     | 12.8     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 344      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 511      |
# | train/             |          |
# |    actor_loss      | -2.47    |
# |    critic_loss     | 0.0485   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 410      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.5     |
# |    ep_rew_mean     | 12.5     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 343      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 549      |
# | train/             |          |
# |    actor_loss      | -2.64    |
# |    critic_loss     | 0.0172   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 448      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.2     |
# |    ep_rew_mean     | 12.2     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 341      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 584      |
# | train/             |          |
# |    actor_loss      | -2.74    |
# |    critic_loss     | 0.0396   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 483      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 12       |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 340      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 624      |
# | train/             |          |
# |    actor_loss      | -2.93    |
# |    critic_loss     | 0.0316   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 523      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.8     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 338      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 659      |
# | train/             |          |
# |    actor_loss      | -2.86    |
# |    critic_loss     | 0.0361   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 558      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.6     |
# |    ep_rew_mean     | 11.6     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 337      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 698      |
# | train/             |          |
# |    actor_loss      | -3.16    |
# |    critic_loss     | 0.0351   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 597      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.5     |
# |    ep_rew_mean     | 11.5     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 336      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 736      |
# | train/             |          |
# |    actor_loss      | -3.2     |
# |    critic_loss     | 0.0452   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 635      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.4     |
# |    ep_rew_mean     | 11.4     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 335      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 777      |
# | train/             |          |
# |    actor_loss      | -3.31    |
# |    critic_loss     | 0.036    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 676      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.3     |
# |    ep_rew_mean     | 11.3     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 334      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 814      |
# | train/             |          |
# |    actor_loss      | -3.39    |
# |    critic_loss     | 0.0455   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 713      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.2     |
# |    ep_rew_mean     | 11.2     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 333      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 849      |
# | train/             |          |
# |    actor_loss      | -3.57    |
# |    critic_loss     | 0.0324   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 748      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.1     |
# |    ep_rew_mean     | 11.1     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 333      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 888      |
# | train/             |          |
# |    actor_loss      | -3.72    |
# |    critic_loss     | 0.0317   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 787      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11       |
# |    ep_rew_mean     | 11       |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 332      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 926      |
# | train/             |          |
# |    actor_loss      | -3.75    |
# |    critic_loss     | 0.0293   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 825      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.9     |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 332      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 962      |
# | train/             |          |
# |    actor_loss      | -3.82    |
# |    critic_loss     | 0.0295   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 861      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.9     |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 331      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 999      |
# | train/             |          |
# |    actor_loss      | -3.92    |
# |    critic_loss     | 0.0408   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 898      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.8     |
# |    ep_rew_mean     | 10.8     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 331      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1037     |
# | train/             |          |
# |    actor_loss      | -4.12    |
# |    critic_loss     | 0.0146   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 936      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.8     |
# |    ep_rew_mean     | 10.8     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 330      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1076     |
# | train/             |          |
# |    actor_loss      | -4.06    |
# |    critic_loss     | 0.0284   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 975      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.3     |
# |    ep_rew_mean     | 10.3     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 330      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1115     |
# | train/             |          |
# |    actor_loss      | -4.22    |
# |    critic_loss     | 0.0388   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1014     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.76     |
# |    ep_rew_mean     | 9.76     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 329      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1154     |
# | train/             |          |
# |    actor_loss      | -4.25    |
# |    critic_loss     | 0.0553   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1053     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.48     |
# |    ep_rew_mean     | 9.48     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 329      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1191     |
# | train/             |          |
# |    actor_loss      | -4.27    |
# |    critic_loss     | 0.0264   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1090     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.47     |
# |    ep_rew_mean     | 9.47     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 329      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1228     |
# | train/             |          |
# |    actor_loss      | -4.35    |
# |    critic_loss     | 0.0333   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1127     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.46     |
# |    ep_rew_mean     | 9.46     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 328      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1266     |
# | train/             |          |
# |    actor_loss      | -4.36    |
# |    critic_loss     | 0.0168   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1165     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.45     |
# |    ep_rew_mean     | 9.45     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 325      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1303     |
# | train/             |          |
# |    actor_loss      | -4.62    |
# |    critic_loss     | 0.0273   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1202     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.43     |
# |    ep_rew_mean     | 9.43     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 326      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1341     |
# | train/             |          |
# |    actor_loss      | -4.54    |
# |    critic_loss     | 0.0124   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1240     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.41     |
# |    ep_rew_mean     | 9.41     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 327      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1379     |
# | train/             |          |
# |    actor_loss      | -4.54    |
# |    critic_loss     | 0.0437   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1278     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.43     |
# |    ep_rew_mean     | 9.43     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 327      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1417     |
# | train/             |          |
# |    actor_loss      | -4.49    |
# |    critic_loss     | 0.0205   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1316     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.46     |
# |    ep_rew_mean     | 9.46     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 328      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1457     |
# | train/             |          |
# |    actor_loss      | -4.64    |
# |    critic_loss     | 0.0134   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1356     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.45     |
# |    ep_rew_mean     | 9.45     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 328      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1494     |
# | train/             |          |
# |    actor_loss      | -4.82    |
# |    critic_loss     | 0.0328   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1393     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.4     |
# |    ep_rew_mean     | 11.4     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 331      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1727     |
# | train/             |          |
# |    actor_loss      | -6.19    |
# |    critic_loss     | 0.408    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1626     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | 27.1     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 338      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 3330     |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.887    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3229     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.8     |
# |    ep_rew_mean     | 39.8     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 335      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 4641     |
# | train/             |          |
# |    actor_loss      | -24.8    |
# |    critic_loss     | 0.374    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4540     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.2     |
# |    ep_rew_mean     | 46.2     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 334      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 5320     |
# | train/             |          |
# |    actor_loss      | -29.7    |
# |    critic_loss     | 0.482    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5219     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.9     |
# |    ep_rew_mean     | 51.9     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 333      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 5923     |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 0.405    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5822     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.9     |
# |    ep_rew_mean     | 56.9     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 332      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 6469     |
# | train/             |          |
# |    actor_loss      | -37.8    |
# |    critic_loss     | 1.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6368     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62.5     |
# |    ep_rew_mean     | 62.5     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 330      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 7067     |
# | train/             |          |
# |    actor_loss      | -41.6    |
# |    critic_loss     | 0.514    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6966     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 68.6     |
# |    ep_rew_mean     | 68.6     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 330      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 7709     |
# | train/             |          |
# |    actor_loss      | -43.8    |
# |    critic_loss     | 0.452    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7608     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.6     |
# |    ep_rew_mean     | 74.6     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 329      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 8348     |
# | train/             |          |
# |    actor_loss      | -47.5    |
# |    critic_loss     | 0.383    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8247     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.4     |
# |    ep_rew_mean     | 81.4     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 328      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 9066     |
# | train/             |          |
# |    actor_loss      | -50.1    |
# |    critic_loss     | 0.755    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8965     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.8     |
# |    ep_rew_mean     | 88.8     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 327      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 9842     |
# | train/             |          |
# |    actor_loss      | -52.9    |
# |    critic_loss     | 0.327    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9741     |
# ---------------------------------
# Training TD3...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 20       |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 9113     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 80       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18       |
# |    ep_rew_mean     | 18       |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 1176     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | -1.03    |
# |    critic_loss     | 0.00823  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.8     |
# |    ep_rew_mean     | 27.8     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 511      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 333      |
# | train/             |          |
# |    actor_loss      | -1.44    |
# |    critic_loss     | 0.0152   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 232      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | 26.4     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 471      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 422      |
# | train/             |          |
# |    actor_loss      | -1.68    |
# |    critic_loss     | 0.0161   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 321      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | 23.4     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 456      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 468      |
# | train/             |          |
# |    actor_loss      | -1.77    |
# |    critic_loss     | 0.0314   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 367      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | 21.3     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 446      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 511      |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 0.0433   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 410      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | 19.6     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 439      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 550      |
# | train/             |          |
# |    actor_loss      | -1.89    |
# |    critic_loss     | 0.0313   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 449      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.3     |
# |    ep_rew_mean     | 18.3     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 432      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 586      |
# | train/             |          |
# |    actor_loss      | -1.97    |
# |    critic_loss     | 0.0521   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 485      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.4     |
# |    ep_rew_mean     | 17.4     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 425      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 627      |
# | train/             |          |
# |    actor_loss      | -2.13    |
# |    critic_loss     | 0.0413   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 526      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.8     |
# |    ep_rew_mean     | 16.8     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 420      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 671      |
# | train/             |          |
# |    actor_loss      | -2.12    |
# |    critic_loss     | 0.0648   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 570      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.1     |
# |    ep_rew_mean     | 16.1     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 415      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 708      |
# | train/             |          |
# |    actor_loss      | -2.14    |
# |    critic_loss     | 0.051    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 607      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.6     |
# |    ep_rew_mean     | 15.6     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 402      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 750      |
# | train/             |          |
# |    actor_loss      | -2.19    |
# |    critic_loss     | 0.0416   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 649      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.2     |
# |    ep_rew_mean     | 15.2     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 399      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 791      |
# | train/             |          |
# |    actor_loss      | -2.3     |
# |    critic_loss     | 0.0747   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 690      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.9     |
# |    ep_rew_mean     | 14.9     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 397      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 835      |
# | train/             |          |
# |    actor_loss      | -2.41    |
# |    critic_loss     | 0.0701   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 734      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.6     |
# |    ep_rew_mean     | 14.6     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 395      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 874      |
# | train/             |          |
# |    actor_loss      | -2.45    |
# |    critic_loss     | 0.0488   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 773      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.4     |
# |    ep_rew_mean     | 14.4     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 393      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 922      |
# | train/             |          |
# |    actor_loss      | -2.56    |
# |    critic_loss     | 0.053    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 821      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 14.2     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 390      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 968      |
# | train/             |          |
# |    actor_loss      | -2.66    |
# |    critic_loss     | 0.0507   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 867      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.4     |
# |    ep_rew_mean     | 14.4     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 383      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1039     |
# | train/             |          |
# |    actor_loss      | -2.7     |
# |    critic_loss     | 0.0402   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 938      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.9     |
# |    ep_rew_mean     | 14.9     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 381      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1136     |
# | train/             |          |
# |    actor_loss      | -2.93    |
# |    critic_loss     | 0.0616   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1035     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.4     |
# |    ep_rew_mean     | 15.4     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 378      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1231     |
# | train/             |          |
# |    actor_loss      | -3.09    |
# |    critic_loss     | 0.0647   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1130     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.3     |
# |    ep_rew_mean     | 16.3     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 375      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1368     |
# | train/             |          |
# |    actor_loss      | -3.43    |
# |    critic_loss     | 0.0745   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1267     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 22.1     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 372      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1941     |
# | train/             |          |
# |    actor_loss      | -4.64    |
# |    critic_loss     | 0.139    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1840     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | 23.5     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 370      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2158     |
# | train/             |          |
# |    actor_loss      | -5.1     |
# |    critic_loss     | 0.0774   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2057     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | 24.1     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 368      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2318     |
# | train/             |          |
# |    actor_loss      | -5.58    |
# |    critic_loss     | 0.171    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2217     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | 24.1     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 367      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2412     |
# | train/             |          |
# |    actor_loss      | -5.67    |
# |    critic_loss     | 0.0838   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2311     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.6     |
# |    ep_rew_mean     | 26.6     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 366      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2736     |
# | train/             |          |
# |    actor_loss      | -6.57    |
# |    critic_loss     | 0.248    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2635     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.6     |
# |    ep_rew_mean     | 31.6     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 366      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 3303     |
# | train/             |          |
# |    actor_loss      | -7.69    |
# |    critic_loss     | 0.163    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3202     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.5     |
# |    ep_rew_mean     | 35.5     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 365      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3886     |
# | train/             |          |
# |    actor_loss      | -8.73    |
# |    critic_loss     | 0.174    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3785     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.5     |
# |    ep_rew_mean     | 38.5     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 365      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 4269     |
# | train/             |          |
# |    actor_loss      | -9.29    |
# |    critic_loss     | 0.316    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4168     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.1     |
# |    ep_rew_mean     | 44.1     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 364      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 4882     |
# | train/             |          |
# |    actor_loss      | -10.8    |
# |    critic_loss     | 0.293    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4781     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.2     |
# |    ep_rew_mean     | 51.2     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 361      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 5630     |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 0.547    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5529     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.2     |
# |    ep_rew_mean     | 59.2     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 360      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 6472     |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.586    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6371     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.2     |
# |    ep_rew_mean     | 66.2     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 359      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 7210     |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 0.487    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7109     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.7     |
# |    ep_rew_mean     | 71.7     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 359      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 7794     |
# | train/             |          |
# |    actor_loss      | -15.3    |
# |    critic_loss     | 0.673    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7693     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.4     |
# |    ep_rew_mean     | 74.4     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 358      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 8112     |
# | train/             |          |
# |    actor_loss      | -15.9    |
# |    critic_loss     | 0.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8011     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.3     |
# |    ep_rew_mean     | 79.3     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 358      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 8639     |
# | train/             |          |
# |    actor_loss      | -17.2    |
# |    critic_loss     | 1.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8538     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.2     |
# |    ep_rew_mean     | 84.2     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 358      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 9165     |
# | train/             |          |
# |    actor_loss      | -18      |
# |    critic_loss     | 0.785    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9064     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.4     |
# |    ep_rew_mean     | 88.4     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 357      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 9635     |
# | train/             |          |
# |    actor_loss      | -18.8    |
# |    critic_loss     | 0.589    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9534     |
# ---------------------------------
# Training SAC...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 20       |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 8568     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 80       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | 20.5     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 404      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | -2.43    |
# |    critic_loss     | 0.115    |
# |    ent_coef        | 0.982    |
# |    ent_coef_loss   | -0.0313  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 289      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 247      |
# | train/             |          |
# |    actor_loss      | -3.03    |
# |    critic_loss     | 0.0989   |
# |    ent_coef        | 0.957    |
# |    ent_coef_loss   | -0.0733  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 146      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | 20.9     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 257      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 334      |
# | train/             |          |
# |    actor_loss      | -3.5     |
# |    critic_loss     | 0.142    |
# |    ent_coef        | 0.933    |
# |    ent_coef_loss   | -0.116   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 233      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 22.1     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 238      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 443      |
# | train/             |          |
# |    actor_loss      | -4.16    |
# |    critic_loss     | 0.204    |
# |    ent_coef        | 0.903    |
# |    ent_coef_loss   | -0.172   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 342      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | 23.4     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 229      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 561      |
# | train/             |          |
# |    actor_loss      | -4.79    |
# |    critic_loss     | 0.166    |
# |    ent_coef        | 0.871    |
# |    ent_coef_loss   | -0.229   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 460      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | 25.1     |
# ...
# |    ep_rew_mean     | 81.6     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 191      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 5872     |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 0.386    |
# |    ent_coef        | 0.195    |
# |    ent_coef_loss   | -1.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5771     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.4     |
# |    ep_rew_mean     | 93.4     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 190      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 7099     |
# | train/             |          |
# |    actor_loss      | -32.4    |
# |    critic_loss     | 1.69     |
# |    ent_coef        | 0.137    |
# |    ent_coef_loss   | -2.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6998     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 189      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 8755     |
# | train/             |          |
# |    actor_loss      | -36.8    |
# |    critic_loss     | 0.338    |
# |    ent_coef        | 0.0852   |
# |    ent_coef_loss   | -2.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8654     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | 118      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 190      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 9920     |
# | train/             |          |
# |    actor_loss      | -38.8    |
# |    critic_loss     | 0.814    |
# |    ent_coef        | 0.0627   |
# |    ent_coef_loss   | -2.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9819     |
# ---------------------------------
# Training D4PG...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | 20       |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 9553     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 80       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 21.4     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 389      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 171      |
# | train/             |          |
# |    actor_loss      | -2.36    |
# |    critic_loss     | 0.0268   |
# |    ent_coef        | 0.98     |
# |    ent_coef_loss   | -0.0347  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 283      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 247      |
# | train/             |          |
# |    actor_loss      | -2.68    |
# |    critic_loss     | 0.0194   |
# |    ent_coef        | 0.957    |
# |    ent_coef_loss   | -0.0734  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 146      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 21.1     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 242      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 338      |
# | train/             |          |
# |    actor_loss      | -3.08    |
# |    critic_loss     | 0.0291   |
# |    ent_coef        | 0.932    |
# |    ent_coef_loss   | -0.117   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 237      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | 21.3     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 224      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 426      |
# | train/             |          |
# |    actor_loss      | -3.55    |
# |    critic_loss     | 0.0333   |
# |    ent_coef        | 0.907    |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 325      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 216      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 494      |
# | train/             |          |
# |    actor_loss      | -3.9     |
# |    critic_loss     | 0.0429   |
# |    ent_coef        | 0.889    |
# |    ent_coef_loss   | -0.197   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 393      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | 22.5     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 206      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 629      |
# | train/             |          |
# |    actor_loss      | -4.56    |
# |    critic_loss     | 0.0518   |
# |    ent_coef        | 0.854    |
# |    ent_coef_loss   | -0.265   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 528      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 21.8     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 203      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 699      |
# | train/             |          |
# |    actor_loss      | -4.99    |
# |    critic_loss     | 0.0414   |
# |    ent_coef        | 0.836    |
# |    ent_coef_loss   | -0.301   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 598      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 22.2     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 199      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 801      |
# | train/             |          |
# |    actor_loss      | -5.63    |
# |    critic_loss     | 0.0485   |
# |    ent_coef        | 0.811    |
# |    ent_coef_loss   | -0.364   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 700      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 22.1     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 196      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 884      |
# | train/             |          |
# |    actor_loss      | -5.94    |
# |    critic_loss     | 0.0596   |
# |    ent_coef        | 0.791    |
# |    ent_coef_loss   | -0.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 783      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | 22.7     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 193      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 998      |
# | train/             |          |
# |    actor_loss      | -6.53    |
# |    critic_loss     | 0.0904   |
# |    ent_coef        | 0.764    |
# |    ent_coef_loss   | -0.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 897      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23       |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 191      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1103     |
# | train/             |          |
# |    actor_loss      | -7.11    |
# |    critic_loss     | 0.0932   |
# |    ent_coef        | 0.741    |
# |    ent_coef_loss   | -0.488   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1002     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.2     |
# |    ep_rew_mean     | 23.2     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 190      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1208     |
# | train/             |          |
# |    actor_loss      | -7.63    |
# |    critic_loss     | 0.0895   |
# |    ent_coef        | 0.719    |
# |    ent_coef_loss   | -0.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1107     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.3     |
# |    ep_rew_mean     | 23.3     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 189      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1305     |
# | train/             |          |
# |    actor_loss      | -8.06    |
# |    critic_loss     | 0.113    |
# |    ent_coef        | 0.699    |
# |    ent_coef_loss   | -0.571   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1204     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | 27.1     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 185      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1626     |
# | train/             |          |
# |    actor_loss      | -9.8     |
# |    critic_loss     | 0.106    |
# |    ent_coef        | 0.638    |
# |    ent_coef_loss   | -0.651   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1525     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.1     |
# |    ep_rew_mean     | 30.1     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 184      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1924     |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 0.155    |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.708   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1823     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.6     |
# |    ep_rew_mean     | 35.6     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 184      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2423     |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.0839   |
# |    ent_coef        | 0.514    |
# |    ent_coef_loss   | -0.951   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2322     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.3     |
# |    ep_rew_mean     | 44.3     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 183      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 3188     |
# | train/             |          |
# |    actor_loss      | -17.5    |
# |    critic_loss     | 0.14     |
# |    ent_coef        | 0.417    |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3087     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53       |
# |    ep_rew_mean     | 53       |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 183      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 4031     |
# | train/             |          |
# |    actor_loss      | -19.9    |
# |    critic_loss     | 0.217    |
# |    ent_coef        | 0.328    |
# |    ent_coef_loss   | -1.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3930     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.6     |
# |    ep_rew_mean     | 64.6     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 183      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 5165     |
# | train/             |          |
# |    actor_loss      | -24.7    |
# |    critic_loss     | 0.177    |
# |    ent_coef        | 0.236    |
# |    ent_coef_loss   | -1.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5064     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.1     |
# |    ep_rew_mean     | 73.1     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 184      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 6138     |
# | train/             |          |
# |    actor_loss      | -28.3    |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.178    |
# |    ent_coef_loss   | -2.15    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6037     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83       |
# |    ep_rew_mean     | 83       |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 182      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 7304     |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.127    |
# |    ent_coef_loss   | -2.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7203     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.9     |
# |    ep_rew_mean     | 91.9     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 182      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 8459     |
# | train/             |          |
# |    actor_loss      | -33.8    |
# |    critic_loss     | 0.165    |
# |    ent_coef        | 0.091    |
# |    ent_coef_loss   | -2.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8358     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 181      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 9712     |
# | train/             |          |
# |    actor_loss      | -39.4    |
# |    critic_loss     | 0.188    |
# |    ent_coef        | 0.0632   |
# |    ent_coef_loss   | -3.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9611     |
# ---------------------------------
# Training data saved to training_rewards.pkl

# %%
    plot_saved_data(os.path.join(SAVE_DIR, "training_rewards.pkl"))

# %%
env_name = "CartPole-v1"
# render_saved_model(os.path.join(SAVE_DIR, "DDPG_cartpole.zip"), env_name)
render_saved_model(os.path.join(SAVE_DIR, "SAC_cartpole.zip"), env_name)

# %%
def plot_all_algorithms_together(pkl_file):
    """
    Plot all rewards from saved pkl file in a single plot.
    """
    rewards_df = pd.read_pickle(pkl_file)
    rewards_df = rewards_df.dropna(how='all', axis=1)

    if rewards_df.empty:
        print("No rewards data to plot.")
        return

    # Plot all algorithms on the same figure
    plt.figure(figsize=(12, 8))
    for column in rewards_df.columns:
        plt.plot(rewards_df.index, rewards_df[column], label=column)

    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.ylim((0, 550))
    plt.title("Training Rewards for All Algorithms on CartPole-v1")
    plt.legend()
    plt.grid()
    plt.show()

# %%
plot_all_algorithms_together(os.path.join(SAVE_DIR, "training_rewards.pkl"))
